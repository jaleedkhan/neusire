# %%
# !pwd
# Out:
# /home/jaleed/Jaleed/SG2IM

# %%
# !git clone https://github.com/google/sg2im
# Out:
# Cloning into 'sg2im'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 98 (delta 20), reused 16 (delta 16), pack-reused 59
# Unpacking objects: 100% (98/98), done.

# %%
# %cd sg2im
# Out:
# /home/jaleed/Jaleed/SG2IM/sg2im

# %%
# pre-trained models
# !bash scripts/download_models.sh
# Out:
# --2022-07-21 15:40:14--  https://storage.googleapis.com/sg2im-data/small/coco64.pt
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.116.128, 74.125.193.128, 2a00:1450:400b:c01::80, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.116.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 119806264 (114M) [application/octet-stream]
# Saving to: ‘sg2im-models/coco64.pt’
#
# sg2im-models/coco64 100%[===================>] 114.26M  11.2MB/s    in 10s
#
# 2022-07-21 15:40:25 (11.0 MB/s) - ‘sg2im-models/coco64.pt’ saved [119806264/119806264]
#
# --2022-07-21 15:40:25--  https://storage.googleapis.com/sg2im-data/small/vg64.pt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.193.128, 2a00:1450:400b:c02::80, 2a00:1450:400b:c01::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.193.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached cloudpickle-0.5.3-py2.py3-none-any.whl (13 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 5.4 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#   Using cached dask-0.17.5-py3-none-any.whl (598 kB)
# ...
#   Using cached decorator-4.3.0-py2.py3-none-any.whl (9.2 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 8.7 MB/s eta 0:00:000m eta 0:00:010:01:01
# ...
#   Using cached imageio-2.3.0-py2.py3-none-any.whl (3.3 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 2.0 MB/s eta 0:00:0064.1 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 10.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached networkx-2.1.zip (1.6 MB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 9.5 MB/s eta 0:00:000m eta 0:00:010:01:01
#   Preparing metadata (setup.py) ... done
# ...

# %%
#!sudo apt update
#!sudo apt install -y build-essential
#!gcc --version

# %%
# !pip install numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 9.8 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...

# %%
# !pip install cython
# Out:
# ...
#   Using cached Cython-0.29.30-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...

# %%
# %cd /home/jaleed/Jaleed/SG2IM
#!git clone https://github.com/cocodataset/cocoapi.git
# %cd ./cocoapi/PythonAPI/
# !python setup.py install
# %cd ../..
# Out:
# /home/jaleed/Jaleed/SG2IM
# /home/jaleed/Jaleed/SG2IM/cocoapi/PythonAPI
# running install
# /home/jaleed/anaconda3/envs/sg2im/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# /home/jaleed/anaconda3/envs/sg2im/lib/python3.7/site-packages/setuptools/command/easy_install.py:147: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   EasyInstallDeprecationWarning,
# running bdist_egg
# running egg_info
# writing pycocotools.egg-info/PKG-INFO
# writing dependency_links to pycocotools.egg-info/dependency_links.txt
# writing requirements to pycocotools.egg-info/requires.txt
# writing top-level names to pycocotools.egg-info/top_level.txt
# reading manifest file 'pycocotools.egg-info/SOURCES.txt'
# writing manifest file 'pycocotools.egg-info/SOURCES.txt'
# ...

# %%
import os,shutil;
if not os.path.exists('/home/jaleed/Jaleed/SG2IM/datasets/vg'):
    os.mkdir('/home/jaleed/Jaleed/SG2IM/datasets/')
    os.mkdir('/home/jaleed/Jaleed/SG2IM/datasets/vg')
    oc.
VG_DIR = '/home/jaleed/Jaleed/SG2IM/datasets/vg'

# %%
# !ls /home/jaleed/Jaleed/ModelsNDatasets/VG
# Out:
# attribute_synsets.json	images.zip	     relationship_alias.txt
# image_data.json		object_alias.txt     relationships.json
# images			objects.json	     relationship_synsets.json
# images2.zip		object_synsets.json

# %%
#Install if unzip doesn't work
#!apt-get install zip unzip

# %%
#!wget https://visualgenome.org/static/data/dataset/objects.json.zip -O $VG_DIR/objects.json.zip
#!unzip -qq -n $VG_DIR/objects.json.zip -d $VG_DIR
#!rm -rf $VG_DIR/objects.json.zip

#!wget https://visualgenome.org/static/data/dataset/attributes.json.zip -O $VG_DIR/attributes.json.zip
#!unzip -qq -n $VG_DIR/attributes.json.zip -d $VG_DIR
#!rm -rf $VG_DIR/attributes.json.zip

#!wget https://visualgenome.org/static/data/dataset/relationships.json.zip -O $VG_DIR/relationships.json.zip
#!unzip -qq -n $VG_DIR/relationships.json.zip -d $VG_DIR
#!rm -rf $VG_DIR/relationships.json.zip

#!wget https://visualgenome.org/static/data/dataset/object_alias.txt -O $VG_DIR/object_alias.txt
#!wget https://visualgenome.org/static/data/dataset/relationship_alias.txt -O $VG_DIR/relationship_alias.txt

#!wget https://visualgenome.org/static/data/dataset/image_data.json.zip -O $VG_DIR/image_data.json.zip
#!unzip -qq -n $VG_DIR/image_data.json.zip -d $VG_DIR
#!rm -rf $VG_DIR/image_data.json.zip

#!wget https://cs.stanford.edu/people/rak248/VG_100K_2/images.zip -O $VG_DIR/images.zip
#!unzip -qq -n $VG_DIR/images.zip -d $VG_DIR/images
#!rm -rf $VG_DIR/images.zip

#!wget https://cs.stanford.edu/people/rak248/VG_100K_2/images2.zip -O $VG_DIR/images2.zip
#!unzip -qq -n $VG_DIR/images2.zip -d $VG_DIR/images
#!rm -rf $VG_DIR/images2.zip

#import boto3
#boto3.Session().resource('s3').Bucket('jaleed-bucket').download_file('vg/images.zip','/root/Sik_SG2IM/SG2IM/datasets/vg/images.zip')
#boto3.Session().resource('s3').Bucket('jaleed-bucket').download_file('vg/images2.zip','/root/Sik_SG2IM/SG2IM/datasets/vg/images2.zip')
#!unzip -qq -n $VG_DIR/images.zip -d $VG_DIR/images
#!unzip -qq -n $VG_DIR/images2.zip -d $VG_DIR/images

# %%
#!ls -laSh /root/Sik_SG2IM/SG2IM/datasets/vg

# %%
#!find /root/Sik_SG2IM/SG2IM/datasets/vg/images/VG_100K -type f -print | wc -l
#!find /root/Sik_SG2IM/SG2IM/datasets/vg/images/VG_100K_2 -type f -print | wc -l

# %%
# !conda install -y pytorch=0.4.1 torchvision cudatoolkit=10.1 -c pytorch
#!conda install -y pytorch=0.4.1 torchvision cuda92 -c pytorch
#!pip install torch==0.4.1+cu92 -f https://download.pytorch.org/whl/cu92/torch_stable.html
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jaleed/anaconda3/envs/sg2im
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - pytorch=0.4.1
#     - torchvision
#
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        pkgs/main/linux-64::cudatoolkit-10.1.243-h6bb024c_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install h5py
# !pip uninstall -y matplotlib
# !pip install Pillow==6.1
# Out:
# ...
# Found existing installation: matplotlib 3.5.2
# Uninstalling matplotlib-3.5.2:
#   Successfully uninstalled matplotlib-3.5.2
# ...
#   Using cached Pillow-6.1.0-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.2.0
#     Uninstalling Pillow-9.2.0:
#       Successfully uninstalled Pillow-9.2.0
# ...

# %%
# !pip install sklearn

# %%
# !pip install scipy==1.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 9.0 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# ...

# %%
import h5py
import json
import math
import PIL
from math import floor
from PIL import *
import random

import torch
import numpy as np

# %% [markdown]
# # Dataset pre-processing (skip if using pre-processed dataset)

# %%
#vg_dict = json.load(open('/root/Sik_SG2IM/SG2IM/VG-SGG-dicts-with-attri.json'))
vg_dict = json.load(open('/home/jaleed/Jaleed/SGG/Scene/datasets/vg/VG-SGG-dicts-with-attri.json'))

# %%
vg_dict.keys()
# Out:
# dict_keys(['object_count', 'idx_to_label', 'predicate_to_idx', 'predicate_count', 'idx_to_predicate', 'label_to_idx', 'attribute_count', 'idx_to_attribute', 'attribute_to_idx'])

# %%
sorted = []
for x in vg_dict['predicate_count'].keys():
    sorted.append(vg_dict['predicate_count'][x])

# %%
import numpy as np
np.sort(sorted)
# Out:
# array([  1740,   1853,   1869,   1914,   1925,   1973,   1996,   2065,
#          2241,   2253,   2312,   2380,   2517,   2721,   2945,   3083,
#          3092,   3095,   3288,   3411,   3477,   3490,   3624,   3739,
#          3806,   3810,   4613,   4688,   5213,   8856,   9145,   9317,
#          9894,   9903,  10190,  13715,  14185,  15457,  18643,  22596,
#         41356,  42722,  47341,  66425,  96589, 136099, 146339, 251756,
#        277936, 712409])

# %%
img_list = []

# %%
obj_data = json.load(open('/home/jaleed/Jaleed/ModelsNDatasets/VG/objects.json'))
rel_data = json.load(open('/home/jaleed/Jaleed/ModelsNDatasets/VG/relationships.json'))

# %%
vg_dict['predicate_count']
# Out:
# {'and': 3477,
#  'says': 2241,
#  'belonging to': 3288,
#  'over': 9317,
#  'parked on': 2721,
#  'growing on': 1853,
#  'standing on': 14185,
#  'made of': 2380,
#  'part of': 2065,
#  'attached to': 10190,
#  'at': 9903,
#  'in': 251756,
#  'hanging from': 9894,
#  'wears': 15457,
#  'in front of': 13715,
#  'from': 2945,
#  'for': 9145,
#  'lying on': 1869,
#  'to': 2517,
#  'behind': 41356,
#  'flying in': 1973,
#  'looking at': 3083,
#  'on back of': 1914,
#  'holding': 42722,
#  'under': 22596,
#  'laying on': 3739,
#  'riding': 8856,
#  'has': 277936,
#  'across': 1996,
#  'wearing': 136099,
#  'walking on': 4613,
#  'eating': 4688,
#  'above': 47341,
#  'watching': 3490,
#  'walking in': 1740,
#  'sitting on': 18643,
#  'between': 3411,
#  'covered in': 2312,
#  'carrying': 5213,
#  'using': 1925,
#  'along': 3624,
#  'with': 66425,
#  'on': 712409,
#  'covering': 3806,
#  'of': 146339,
#  'against': 3092,
#  'mounted on': 2253,
#  'near': 96589,
#  'painted on': 3095,
# ...

# %%
obj_data[0].keys()
# Out:
# dict_keys(['image_id', 'objects', 'image_url'])

# %%
valid_img = []
for i in range(len(obj_data)):
    img_id = obj_data[i]['image_id']
    img_objects = []
    objects = obj_data[i]['objects']
    for __, name in enumerate(objects):
        img_objects.append(name['names'][0])
    for __, key in enumerate(img_objects):
        if key in vg_dict['object_count']:
            valid_img.append(img_id)
            break
        elif key in vg_dict['predicate_count']:
            valid_img.append(img_id)
            break
        else:
            continue

# %%
import sklearn.model_selection as D
random.shuffle(valid_img)
train, test = D.train_test_split(valid_img, test_size = 0.2, train_size = 0.8)
test, val = D.train_test_split(test, test_size = 0.5, train_size = 0.5)

# %%
KT_split = {"train": train,
            "test": test,
            "val": val
            }

with open("/home/jaleed/Jaleed/SG2IM/sg2im/sg2im/data/KT_vg_split.json", 'w') as outfile:
    json.dump(KT_split, outfile)

# %%
len(valid_img)
# Out:
# 104922

# %%
def line_prepender(filename, line):
    with open(filename, 'r+') as f:
        content = f.read()
        f.seek(0, 0)
        f.write(line.rstrip('\r\n') + '\n' + content)

file1 = r"/home/jaleed/Jaleed/SG2IM/sg2im/scripts/preprocess_vg.py"

to_add = "import sys \nsys.path.append('/home/jaleed/Jaleed/SG2IM/')"

line_prepender(filename=file1, line=to_add)

# %%
import gc
gc.collect()
# Out:
# 186

# %%
# %cd sg2im
# Out:
# /home/jaleed/Jaleed/SG2IM/sg2im

# %%
# !python scripts/preprocess_vg.py --splits_json /home/jaleed/Jaleed/SG2IM/sg2im/sg2im/data/KT_vg_split.json \
--min_object_instances 2050 \
--min_object_instances 850 \
--max_objects_per_image 40 \
--max_objects_per_image 40 \
--min_relationship_instances 1700 \
--min_image_size 64 \
--min_object_size 16 \
--max_relationships_per_image 40
# Out:
# Loading image info from "/home/jaleed/Jaleed/ModelsNDatasets/VG/image_data.json"
# Removed 2 images from split "train" for being too small
# Removed 0 images from split "test" for being too small
# Removed 0 images from split "val" for being too small
# Loading aliases from "/home/jaleed/Jaleed/ModelsNDatasets/VG/object_alias.txt"
# Loading aliases from "/home/jaleed/Jaleed/ModelsNDatasets/VG/relationship_alias.txt"
# Loading objects from "/home/jaleed/Jaleed/ModelsNDatasets/VG/objects.json"
# Making object vocab from 83935 training images
# Found 373 object categories with >= 850 training instances
# Loading attributes from "/home/jaleed/Jaleed/ModelsNDatasets/VG/attributes.json"
# Making attribute vocab from 83935 training images
# Found 79 attribute categories with >= 2000 training instances
# Skipped 449038 objects with size < 16
# After filtering there are 1506571 object instances
# Loading relationshps from "/home/jaleed/Jaleed/ModelsNDatasets/VG/relationships.json"
# ...

# %% [markdown]
# # Training  SG2IM (requires GPU)

# %%
#%cd /root/Sik_SG2IM/SG2IM/datasets/vg/
#!wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1WhXzPdlNw4-5yzcBEPcT0859_lHj4OGD' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1WhXzPdlNw4-5yzcBEPcT0859_lHj4OGD" -O train.h5 && rm -rf /tmp/cookies.txt
#!wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1wC3V225GzNoFSl2D_xG26rhq7YVJwc9l' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1wC3V225GzNoFSl2D_xG26rhq7YVJwc9l" -O test.h5 && rm -rf /tmp/cookies.txt
#!wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1ECaLze_hnT-i6FKAbgKyLq0-8Ns7LlGQ' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1ECaLze_hnT-i6FKAbgKyLq0-8Ns7LlGQ" -O val.h5 && rm -rf /tmp/cookies.txt
#!wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=12XblrpKSziC-IotuoRmkZ2dEX5AakKIF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=12XblrpKSziC-IotuoRmkZ2dEX5AakKIF" -O vocab.json && rm -rf /tmp/cookies.txt

# %%
# !ls sg2im/data
# Out:
# coco.py  __init__.py  KT_vg_split.json	utils.py  vg.py  vg_splits.json

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Fri_Feb__8_19:08:17_PST_2019
# Cuda compilation tools, release 10.1, V10.1.105

# %%
# !python scripts/train.py \
    --dataset 'vg' --image_size '128,128' --checkpoint_every 1000  \
    --save_loss_metrics_every 100 --eval_mode_after 5000 --learning_rate 1e-4 \
    --num_iterations 30000 --loader_num_workers 0 --restore_from_checkpoint 1
# Out:
# Namespace(ac_loss_weight=0.1, activation='leakyrelu-0.2', batch_size=32, bbox_pred_loss_weight=10, checkpoint_every=1000, checkpoint_name='checkpoint', checkpoint_start_from=None, coco_include_other=False, coco_stuff_only=True, coco_train_image_dir='datasets/coco/images/train2017', coco_train_instances_json='datasets/coco/annotations/instances_train2017.json', coco_train_stuff_json='datasets/coco/annotations/stuff_train2017.json', coco_val_image_dir='datasets/coco/images/val2017', coco_val_instances_json='datasets/coco/annotations/instances_val2017.json', coco_val_stuff_json='datasets/coco/annotations/stuff_val2017.json', crop_size=32, d_activation='leakyrelu-0.2', d_clip=None, d_img_arch='C4-64-2,C4-128-2,C4-256-2', d_img_weight=1.0, d_normalization='batch', d_obj_arch='C4-64-2,C4-128-2,C4-256-2', d_obj_weight=1.0, d_padding='valid', dataset='vg', discriminator_loss_weight=0.01, embedding_dim=128, eval_mode_after=5000, gan_loss_type='gan', gconv_dim=128, gconv_hidden_dim=512, gconv_
# ...

# %% [markdown]
# # Testing on scene graphs from SGG-VG

# %%
import json
custom_data_info = json.load(open('/root/Sik_SG2IM/SG2IM/custom_data_info.json'))
custom_prediction = json.load(open('/root/Sik_SG2IM/SG2IM/custom_prediction.json'))

# %%
def print_list(name, input_list, scores=None):
    for i, item in enumerate(input_list):
        if scores == None:
            print(name + ' ' + str(i) + ': ' + str(item))
        else:
            print(name + ' ' + str(i) + ': ' + str(item) + '; score: ' + str(scores[i]))

# %%
image_idx = 0
box_topk = 5 # select top k bounding boxes
rel_topk = 20 # select top k relationships
ind_to_classes = custom_data_info['ind_to_classes']
ind_to_predicates = custom_data_info['ind_to_predicates']

# Display results
#image_path = custom_data_info['idx_to_files'][image_idx] #keep this if you arent purging directories in im2scene function
boxes = custom_prediction[str(image_idx)]['bbox'][:box_topk]
box_labels = custom_prediction[str(image_idx)]['bbox_labels'][:box_topk]
box_scores = custom_prediction[str(image_idx)]['bbox_scores'][:box_topk]
all_rel_labels = custom_prediction[str(image_idx)]['rel_labels']
all_rel_scores = custom_prediction[str(image_idx)]['rel_scores']
all_rel_pairs = custom_prediction[str(image_idx)]['rel_pairs']

for i in range(len(box_labels)):
    box_labels[i] = ind_to_classes[box_labels[i]]

rel_labels = []
rel_scores = []
for i in range(len(all_rel_pairs)):
    if all_rel_pairs[i][0] < box_topk and all_rel_pairs[i][1] < box_topk:
        rel_scores.append(all_rel_scores[i])
        label = str(all_rel_pairs[i][0]) + '_' + box_labels[all_rel_pairs[i][0]] + ' => ' + ind_to_predicates[all_rel_labels[i]] + ' => ' + str(all_rel_pairs[i][1]) + '_' + box_labels[all_rel_pairs[i][1]]
        rel_labels.append(label)

rel_labels = rel_labels[:rel_topk]
rel_scores = rel_scores[:rel_topk]

print('*' * 50)
print_list('box_labels', box_labels, box_scores)
print('*' * 50)
print_list('rel_labels', rel_labels, rel_scores)

rel_labels = []
rel_scores = []
label = []
for i in range(len(all_rel_pairs)):
    if all_rel_pairs[i][0] < box_topk and all_rel_pairs[i][1] < box_topk:
        rel_scores.append(all_rel_scores[i])
        label.append(all_rel_pairs[i][0]) 
        label.append(ind_to_predicates[all_rel_labels[i]])
        label.append(all_rel_pairs[i][1])
        rel_labels.append(label)
        label = []

rel_labels = rel_labels[:rel_topk]
rel_scores = rel_scores[:rel_topk]

print('*' * 50)
print_list('box_labels', box_labels, box_scores)
print('*' * 50)
print_list('rel_labels', rel_labels, rel_scores)
# Out:
# **************************************************
# box_labels 0: mountain; score: 0.2990840971469879
# box_labels 1: people; score: 0.1773747205734253
# box_labels 2: snow; score: 0.07736901193857193
# box_labels 3: hill; score: 0.05893529951572418
# box_labels 4: mountain; score: 0.050633229315280914
# **************************************************
# rel_labels 0: 4_mountain => behind => 1_people; score: 0.8084304332733154
# rel_labels 1: 3_hill => with => 1_people; score: 0.49698060750961304
# rel_labels 2: 2_snow => with => 1_people; score: 0.44815880060195923
# rel_labels 3: 4_mountain => covered in => 2_snow; score: 0.4454309046268463
# rel_labels 4: 0_mountain => with => 1_people; score: 0.4426213800907135
# rel_labels 5: 1_people => standing on => 2_snow; score: 0.43484681844711304
# rel_labels 6: 1_people => standing on => 3_hill; score: 0.37616369128227234
# rel_labels 7: 1_people => standing on => 0_mountain; score: 0.37080803513526917
# ...

# %%
# Change format of SGs to match SG2IM's format
import json
sg_data ={
    "objects" : box_labels,
    "relationships": rel_labels
    }

with open("sgk.json", "w") as outfile:
    json.dump(sg_data, outfile)

# %%
# Change format of SGs to match SG2IM's format - This one is for pre-trained model (change obj/rel labels) trained on a different subset of VG
# (retrieve list of objects/relationships from vocab of pre-trained model, iterate SG objects and rels and remove those not supported)
import json
from sg2im.model import Sg2ImModel
import torch

ckpt = torch.load('sg2im-models/vg128.pt')
model = Sg2ImModel(**ckpt['model_kwargs'])
sup_objs = model.vocab['object_idx_to_name']
sup_preds = model.vocab['pred_idx_to_name']
box_labels1 = list()
for obj in box_labels:
    if obj in sup_objs:
        box_labels1.append(obj)
rel_labels1 = list()
for rel in rel_labels:
    if (rel[1] in sup_preds) and (box_labels[rel[0]] in sup_objs) and (box_labels[rel[2]] in sup_objs):
        rel_labels1.append(rel)

sg_data ={
   "objects" : box_labels1,
   "relationships": rel_labels1
   }

with open("sgk1.json", "w") as outfile:
    json.dump(sg_data, outfile)

# %%
# Run this cell only once

def line_prepender(filename, line):
    with open(filename, 'r+') as f:
        content = f.read()
        f.seek(0, 0)
        f.write(line.rstrip('\r\n') + '\n' + content)

file1 = r"/root/Sik_SG2IM/SG2IM/scripts/run_model.py"
to_add = "import sys \nsys.path.append('/root/Sik_SG2IM/SG2IM/') \n"
line_prepender(filename=file1, line=to_add)

# %%
# Run SG2IM
import sys
#!python scripts/run_model.py --checkpoint checkpoint_with_model.pt --scene_graphs_json sgk.json --output_dir outputs
# !python scripts/run_model.py --checkpoint sg2im-models/vg64.pt --scene_graphs_json sgk1.json --output_dir outputs

import matplotlib.pyplot as plt
from PIL import Image
img = Image.open('outputs/img000000.png').convert('RGB')
plt.imshow(img)

# %% [markdown]
# # For multiple SGs on s3

# %%
import boto3
import s3fs
import sys
import json
from sg2im.model import Sg2ImModel
import torch

fs = s3fs.S3FileSystem()
ls = fs.ls('s3://jaleed-bucket/jSGG_output')
ls.pop(0) #current dir path not needed

for sg_path in ls:
    # Load SG from s3
    custom_data_info = json.load(fs.open('s3://'+sg_path+'/custom_data_info.json'))
    custom_prediction = json.load(fs.open('s3://'+sg_path+'/custom_prediction.json'))
    
    # Process SG to get obj/rel labels
    image_idx = 0
    box_topk = 5 # select top k bounding boxes
    rel_topk = 20 # select top k relationships
    ind_to_classes = custom_data_info['ind_to_classes']
    ind_to_predicates = custom_data_info['ind_to_predicates']
    boxes = custom_prediction[str(image_idx)]['bbox'][:box_topk]
    box_labels = custom_prediction[str(image_idx)]['bbox_labels'][:box_topk]
    box_scores = custom_prediction[str(image_idx)]['bbox_scores'][:box_topk]
    all_rel_labels = custom_prediction[str(image_idx)]['rel_labels']
    all_rel_scores = custom_prediction[str(image_idx)]['rel_scores']
    all_rel_pairs = custom_prediction[str(image_idx)]['rel_pairs']
    for i in range(len(box_labels)):
        box_labels[i] = ind_to_classes[box_labels[i]]
    rel_labels = []
    rel_scores = []
    label = []
    for i in range(len(all_rel_pairs)):
        if all_rel_pairs[i][0] < box_topk and all_rel_pairs[i][1] < box_topk:
            rel_scores.append(all_rel_scores[i])
            label.append(all_rel_pairs[i][0]) 
            label.append(ind_to_predicates[all_rel_labels[i]])
            label.append(all_rel_pairs[i][1])
            rel_labels.append(label)
            label = []
    rel_labels = rel_labels[:rel_topk]
    rel_scores = rel_scores[:rel_topk]
    
    # Parse to SG2IM format 1/2 (as it is)
    sg_data = {"objects" : box_labels, "relationships": rel_labels}
    with open("sgk.json", "w") as outfile:
        json.dump(sg_data, outfile)
        
    # Parse to SG2IM format 2/2 (after removing obj/rels not supported by pretrained model)
    ckpt = torch.load('sg2im-models/vg128.pt')
    model = Sg2ImModel(**ckpt['model_kwargs'])
    sup_objs = model.vocab['object_idx_to_name']
    sup_preds = model.vocab['pred_idx_to_name']
    box_labels1 = list()
    for obj in box_labels:
        if obj in sup_objs:
            box_labels1.append(obj)
    rel_labels1 = list()
    for rel in rel_labels:
        if (rel[1] in sup_preds) and (box_labels[rel[0]] in sup_objs) and (box_labels[rel[2]] in sup_objs):
            rel_labels1.append(rel)
    sg_data = {"objects" : box_labels1, "relationships": rel_labels1}
    with open("sgk1.json", "w") as outfile:
        json.dump(sg_data, outfile)
    
    # Run SG2IM and save output to s3 
    # !python scripts/run_model.py --checkpoint checkpoint_with_model.pt --scene_graphs_json sgk.json --output_dir outputs
    boto3.client('s3').upload_file('outputs/img000000.png', 'jaleed-bucket', 'SG2IM_output/sgg_vg_trained/'+sg_path.split('jSGG_output/')[1]+'.png')
    # !python scripts/run_model.py --checkpoint sg2im-models/vg64.pt --scene_graphs_json sgk1.json --output_dir outputs
    boto3.client('s3').upload_file('outputs/img000000.png', 'jaleed-bucket', 'SG2IM_output/pretrained_vg64/'+sg_path.split('jSGG_output/')[1]+'.png')
    # !python scripts/run_model.py --checkpoint sg2im-models/vg128.pt --scene_graphs_json sgk1.json --output_dir outputs
    boto3.client('s3').upload_file('outputs/img000000.png', 'jaleed-bucket', 'SG2IM_output/pretrained_vg128/'+sg_path.split('jSGG_output/')[1]+'.png')
# Out:
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/upsampling.py:122: UserWarning: nn.Upsampling is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.Upsampling is deprecated. Use nn.functional.interpolate instead.")
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/upsampling.py:122: UserWarning: nn.Upsampling is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.Upsampling is deprecated. Use nn.functional.interpolate instead.")
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
# ...

# %%
# Now repeat the whole process for groundtruth SGs from VG (objects.json and relationships.json)

vg_rels_json = json.load(open('datasets/vg/relationships.json'))
custom_data_info = json.load(open('custom_data_info.json'))
vg_unique_objs = custom_data_info['ind_to_classes']
vg_unique_rels = custom_data_info['ind_to_predicates']

# %%
import boto3
import s3fs
import sys
import json
from sg2im.model import Sg2ImModel
import torch

fs = s3fs.S3FileSystem()
ls = fs.ls('s3://jaleed-bucket/jSGG_output')
ls.pop(0) #current dir path not needed

for sg_path in ls:
    img_id = int(sg_path.split('jSGG_output/')[1].split('.jpg')[0])
    box_labels = list()
    rel_labels = list()
    for img in vg_rels_json:
        if img['image_id'] == img_id:
            for rel in img['relationships']:
                if rel['predicate'].lower() in vg_unique_rels:
                    # in relationships.json, there is either 'name' or 'names' key for subject and object
                    pred = rel['predicate'].lower()
                    if 'name' in rel['subject'].keys():
                        if 'name' in rel['object'].keys():
                            subj = rel['subject']['name']
                            obj = rel['object']['name']
                        else:
                            subj = rel['subject']['name']
                            obj = rel['object']['names'][0]
                    else:
                        if 'name' in rel['object'].keys():
                            subj = rel['subject']['names'][0]
                            obj = rel['object']['name']
                        else:
                            subj = rel['subject']['names'][0]
                            obj = rel['object']['names'][0]
                    if (subj in vg_unique_objs) and (obj in vg_unique_objs):
                        if subj in box_labels:
                            subj_id = box_labels.index(subj)
                        else:
                            box_labels.append(subj)
                            subj_id = box_labels.index(subj)
                        if obj in box_labels:
                            obj_id = box_labels.index(obj)
                        else:
                            box_labels.append(obj)
                            obj_id = box_labels.index(obj)
                        rel_labels.append([subj_id,pred,obj_id])
    
    print(sg_path+'   objs:'+str(len(box_labels))+'   rels:'+str(len(rel_labels)))
    
    # Parse to SG2IM format 1/2 (as it is)
    sg_data = {"objects" : box_labels, "relationships": rel_labels}
    with open("sgk.json", "w") as outfile:
        json.dump(sg_data, outfile)
        
    # Parse to SG2IM format 2/2 (after removing obj/rels not supported by pretrained model)
    ckpt = torch.load('sg2im-models/vg128.pt')
    model = Sg2ImModel(**ckpt['model_kwargs'])
    sup_objs = model.vocab['object_idx_to_name']
    sup_preds = model.vocab['pred_idx_to_name']
    box_labels1 = list()
    for obj in box_labels:
        if obj in sup_objs:
            box_labels1.append(obj)
    rel_labels1 = list()
    for rel in rel_labels:
        if (rel[1] in sup_preds) and (box_labels[rel[0]] in sup_objs) and (box_labels[rel[2]] in sup_objs):
            rel_labels1.append(rel)
    sg_data = {"objects" : box_labels1, "relationships": rel_labels1}
    with open("sgk1.json", "w") as outfile:
        json.dump(sg_data, outfile)
    
    # Run SG2IM and save output to s3 
    # !python scripts/run_model.py --checkpoint checkpoint_with_model.pt --scene_graphs_json sgk.json --output_dir outputs
    boto3.client('s3').upload_file('outputs/img000000.png', 'jaleed-bucket', 'SG2IM_output_gt/sgg_vg_trained/'+sg_path.split('jSGG_output/')[1]+'.png')
    # !python scripts/run_model.py --checkpoint sg2im-models/vg64.pt --scene_graphs_json sgk1.json --output_dir outputs
    boto3.client('s3').upload_file('outputs/img000000.png', 'jaleed-bucket', 'SG2IM_output_gt/pretrained_vg64/'+sg_path.split('jSGG_output/')[1]+'.png')
    # !python scripts/run_model.py --checkpoint sg2im-models/vg128.pt --scene_graphs_json sgk1.json --output_dir outputs
    boto3.client('s3').upload_file('outputs/img000000.png', 'jaleed-bucket', 'SG2IM_output_gt/pretrained_vg128/'+sg_path.split('jSGG_output/')[1]+'.png')
# Out:
# jaleed-bucket/jSGG_output/1.jpg   objs:9   rels:12
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/upsampling.py:122: UserWarning: nn.Upsampling is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.Upsampling is deprecated. Use nn.functional.interpolate instead.")
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/upsampling.py:122: UserWarning: nn.Upsampling is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.Upsampling is deprecated. Use nn.functional.interpolate instead.")
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
# ...

# %%
# !apt-get update -y
# !apt-get install -y zip unzip
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Fetched 252 kB in 1s (277 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.1).
# The following NEW packages will be installed:
#   zip
# ...

# %%
# Download all resulting images from s3 and make a ZIP file

import boto3
import os

s3_client = boto3.client('s3')

def download_dir(prefix, local, bucket, client=s3_client):
    """
    params:
    - prefix: pattern to match in s3
    - local: local path to folder in which to place files
    - bucket: s3 bucket with target contents
    - client: initialized s3 client object
    """
    keys = []
    dirs = []
    next_token = ''
    base_kwargs = {
        'Bucket':bucket,
        'Prefix':prefix,
    }
    while next_token is not None:
        kwargs = base_kwargs.copy()
        if next_token != '':
            kwargs.update({'ContinuationToken': next_token})
        results = client.list_objects_v2(**kwargs)
        contents = results.get('Contents')
        for i in contents:
            k = i.get('Key')
            if k[-1] != '/':
                keys.append(k)
            else:
                dirs.append(k)
        next_token = results.get('NextContinuationToken')
    for d in dirs:
        dest_pathname = os.path.join(local, d)
        if not os.path.exists(os.path.dirname(dest_pathname)):
            os.makedirs(os.path.dirname(dest_pathname))
    for k in keys:
        dest_pathname = os.path.join(local, k)
        if not os.path.exists(os.path.dirname(dest_pathname)):
            os.makedirs(os.path.dirname(dest_pathname))
        client.download_file(bucket, k, dest_pathname)

download_dir('SG2IM_output', 'SG2IM_output', 'jaleed-bucket', client=s3_client)
# !zip -r SG2IM_output.zip SG2IM_output/*
boto3.client('s3').upload_file('SG2IM_output.zip', 'jaleed-bucket', 'SG2IM_output.zip')
# !rm -r SG2IM_output
# !rm SG2IM_output.zip

download_dir('SG2IM_output_gt', 'SG2IM_output_gt', 'jaleed-bucket', client=s3_client)
# !zip -r SG2IM_output_gt.zip SG2IM_output_gt/*
boto3.client('s3').upload_file('SG2IM_output_gt.zip', 'jaleed-bucket', 'SG2IM_output_gt.zip')
# !rm -r SG2IM_output_gt
# !rm SG2IM_output_gt.zip
# Out:
#   adding: SG2IM_output/SG2IM_output/ (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/ (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2373492.jpg.png (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2321240.jpg.png (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2373456.jpg.png (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2373537.jpg.png (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2321222.jpg.png (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2373438.jpg.png (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2373519.jpg.png (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2363000.jpg.png (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2362980.jpg.png (stored 0%)
#   adding: SG2IM_output/SG2IM_output/pretrained_vg64/2373474.jpg.png (stored 0%)
# ...
